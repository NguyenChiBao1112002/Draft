# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# Read Dataset
data = pd.read_csv('./Predict-The-Number-Of-Faecal-Coliforms-And-E.coli-In-The-Water-In-Hong-Kong\'s-Rivers/river-historical-2020-en.csv')
data
# Out:
#     Water Control Zone                          River Station       Dates  \
# 0       Western Buffer  Pai Min Kok (Anglers') Stream     AN1  2020-01-16
# 1       Western Buffer  Pai Min Kok (Anglers') Stream     AN1  2020-03-20
# 2       Western Buffer  Pai Min Kok (Anglers') Stream     AN1  2020-05-14
# 3       Western Buffer  Pai Min Kok (Anglers') Stream     AN1  2020-06-11
# 4       Western Buffer  Pai Min Kok (Anglers') Stream     AN1  2020-09-02
# ..                 ...                            ...     ...         ...
# 660           Deep Bay                Yuen Long Creek     YL4  2020-07-15
# 661           Deep Bay                Yuen Long Creek     YL4  2020-09-16
# 662           Deep Bay                Yuen Long Creek     YL4  2020-10-07
# 663           Deep Bay                Yuen Long Creek     YL4  2020-11-16
# 664           Deep Bay                Yuen Long Creek     YL4  2020-12-02
#
#      Sample No 5-Day Biochemical Oxygen Demand (mg/L) Aluminium (μg/L)  \
# 0            1                                    1.1              <50
# 1            1                                     24              <50
# 2            1                                    1.9               86
# 3            1                                      6              370
# 4            1                                      1              294
# ..         ...                                    ...              ...
# 660          1                                    110              514
# 661          1                                    140               88
# 662          1                                    190              <50
# 663          1                                    130              <50
# 664          1                                    100              <50
#
#      Ammonia-Nitrogen (mg/L) Anionic Surfactants (as Manoxol OT) (mg/L)  \
# 0                      0.280                                       0.06
# 1                      0.029                                       0.07
# 2                      0.180                                        0.1
# 3                      0.061                                      <0.05
# 4                      0.430                                      <0.05
# ..                       ...                                        ...
# 660                    3.700                                       0.75
# 661                    6.300                                        1.5
# 662                   13.000                                        2.3
# 663                    6.900                                        1.3
# 664                    9.000                                          1
#
#     Antimony (μg/L)  ... Total Kjeldahl Nitrogen (mg/L)  \
# 0                <1  ...                            2.1
# 1                <1  ...                            1.5
# 2                <1  ...                           0.97
# 3                <1  ...                            0.3
# 4                <1  ...                            1.1
# ..              ...  ...                            ...
# 660              <1  ...                            5.1
# 661              <1  ...                            8.9
# 662              <1  ...                             21
# 663              <1  ...                             11
# 664              <1  ...                             24
#
#      Total Organic Carbon (mg/L) Total Phosphorus (mg/L) Total Solids (mg/L)  \
# 0                              3                    0.07                 750
# 1                             10                    0.12                 610
# 2                              3                    0.13                 240
# 3                              3                    0.04                 120
# 4                              3                    0.12                 190
# ..                           ...                     ...                 ...
# 660                           19                    0.64                 730
# 661                           47                     1.2                 730
# 662                           84                     2.3                1100
# 663                           33                     1.2                 570
# 664                           16                     3.5                1400
#
#     Total Volatile Solids (mg/L) Turbidity (NTU) Vanadium (μg/L)  \
# 0                            180             0.7              <2
# 1                            120             5.0              <2
# 2                             69             1.5              <2
# 3                             32             9.0              <2
# 4                             79             5.2              <2
# ..                           ...             ...             ...
# 660                          210           134.2              <2
# 661                          210            18.5              <2
# 662                          330            36.3              <2
# 663                          190            15.7              <2
# 664                          280            19.1              <2
#
#     Water Temperature (°C) Zinc (μg/L)  𝐸. 𝑐𝑜𝑙𝑖  (counts/100mL)
# 0                     20.8          62                       30
# 1                     21.3          24                     7400
# 2                     25.8         <10                     1400
# 3                     28.0          18                    10000
# 4                     28.7          10                   320000
# ..                     ...         ...                      ...
# 660                   31.1         <10                  1800000
# 661                   30.3         <10                  4200000
# 662                   27.9          14                  7900000
# 663                   25.2          14                  1000000
# 664                   23.6         <10                   810000
#
# [665 rows x 56 columns]

# %%
data = data.replace('<', '', regex=True)

# %%
data
# Out:
#     Water Control Zone                          River Station       Dates  \
# 0       Western Buffer  Pai Min Kok (Anglers') Stream     AN1  2020-01-16
# 1       Western Buffer  Pai Min Kok (Anglers') Stream     AN1  2020-03-20
# 2       Western Buffer  Pai Min Kok (Anglers') Stream     AN1  2020-05-14
# 3       Western Buffer  Pai Min Kok (Anglers') Stream     AN1  2020-06-11
# 4       Western Buffer  Pai Min Kok (Anglers') Stream     AN1  2020-09-02
# ..                 ...                            ...     ...         ...
# 660           Deep Bay                Yuen Long Creek     YL4  2020-07-15
# 661           Deep Bay                Yuen Long Creek     YL4  2020-09-16
# 662           Deep Bay                Yuen Long Creek     YL4  2020-10-07
# 663           Deep Bay                Yuen Long Creek     YL4  2020-11-16
# 664           Deep Bay                Yuen Long Creek     YL4  2020-12-02
#
#      Sample No 5-Day Biochemical Oxygen Demand (mg/L) Aluminium (μg/L)  \
# 0            1                                    1.1               50
# 1            1                                     24               50
# 2            1                                    1.9               86
# 3            1                                      6              370
# 4            1                                      1              294
# ..         ...                                    ...              ...
# 660          1                                    110              514
# 661          1                                    140               88
# 662          1                                    190               50
# 663          1                                    130               50
# 664          1                                    100               50
#
#      Ammonia-Nitrogen (mg/L) Anionic Surfactants (as Manoxol OT) (mg/L)  \
# 0                      0.280                                       0.06
# 1                      0.029                                       0.07
# 2                      0.180                                        0.1
# 3                      0.061                                       0.05
# 4                      0.430                                       0.05
# ..                       ...                                        ...
# 660                    3.700                                       0.75
# 661                    6.300                                        1.5
# 662                   13.000                                        2.3
# 663                    6.900                                        1.3
# 664                    9.000                                          1
#
#     Antimony (μg/L)  ... Total Kjeldahl Nitrogen (mg/L)  \
# 0                 1  ...                            2.1
# 1                 1  ...                            1.5
# 2                 1  ...                           0.97
# 3                 1  ...                            0.3
# 4                 1  ...                            1.1
# ..              ...  ...                            ...
# 660               1  ...                            5.1
# 661               1  ...                            8.9
# 662               1  ...                             21
# 663               1  ...                             11
# 664               1  ...                             24
#
#      Total Organic Carbon (mg/L) Total Phosphorus (mg/L) Total Solids (mg/L)  \
# 0                              3                    0.07                 750
# 1                             10                    0.12                 610
# 2                              3                    0.13                 240
# 3                              3                    0.04                 120
# 4                              3                    0.12                 190
# ..                           ...                     ...                 ...
# 660                           19                    0.64                 730
# 661                           47                     1.2                 730
# 662                           84                     2.3                1100
# 663                           33                     1.2                 570
# 664                           16                     3.5                1400
#
#     Total Volatile Solids (mg/L) Turbidity (NTU) Vanadium (μg/L)  \
# 0                            180             0.7               2
# 1                            120             5.0               2
# 2                             69             1.5               2
# 3                             32             9.0               2
# 4                             79             5.2               2
# ..                           ...             ...             ...
# 660                          210           134.2               2
# 661                          210            18.5               2
# 662                          330            36.3               2
# 663                          190            15.7               2
# 664                          280            19.1               2
#
#     Water Temperature (°C) Zinc (μg/L)  𝐸. 𝑐𝑜𝑙𝑖  (counts/100mL)
# 0                     20.8          62                       30
# 1                     21.3          24                     7400
# 2                     25.8          10                     1400
# 3                     28.0          18                    10000
# 4                     28.7          10                   320000
# ..                     ...         ...                      ...
# 660                   31.1          10                  1800000
# 661                   30.3          10                  4200000
# 662                   27.9          14                  7900000
# 663                   25.2          14                  1000000
# 664                   23.6          10                   810000
#
# [665 rows x 56 columns]

# %%
data.describe()
# Out:
#        Sample No  Ammonia-Nitrogen (mg/L)  Barium (μg/L)  \
# count      665.0               665.000000     665.000000
# mean         1.0                 1.531412      19.684211
# std          0.0                 3.406697      10.338523
# min          1.0                 0.008000       1.000000
# 25%          1.0                 0.065000      14.000000
# 50%          1.0                 0.230000      18.000000
# 75%          1.0                 1.200000      24.000000
# max          1.0                38.000000      84.000000
#
#        Conductivity (μS/cm)  Dissolved Oxygen (%saturation)  \
# count            665.000000                      665.000000
# mean            5823.082707                       89.193985
# std            11324.795526                       23.087510
# min               38.000000                       14.000000
# 25%              145.000000                       81.000000
# 50%              298.000000                       95.000000
# 75%             3863.000000                      102.000000
# max            53664.000000                      168.000000
#
#        Dissolved Oxygen (mg/L)  Flow (m³/s)          pH  Salinity (psu)  \
# count               665.000000   428.000000  665.000000      665.000000
# mean                  7.121353     0.859762    7.708271        3.463910
# std                   1.917852     4.592105    0.553636        7.017778
# min                   1.100000     0.000000    5.800000        0.000000
# 25%                   6.200000     0.045750    7.300000        0.100000
# 50%                   7.600000     0.138000    7.600000        0.100000
# 75%                   8.300000     0.365000    8.000000        2.000000
# max                  12.800000    75.460000   10.000000       32.800000
#
#        Silica (as SiO₂) (mg/L)  Total Solids (mg/L)  Turbidity (NTU)  \
# count               665.000000           665.000000       665.000000
# mean                 14.116541          4902.879699         8.607519
# std                   5.380845         10290.449099        34.433002
# min                   1.200000            29.000000         0.300000
# 25%                  11.000000           130.000000         1.800000
# 50%                  15.000000           220.000000         3.300000
# 75%                  18.000000          3000.000000         6.900000
# max                  44.000000         68000.000000       788.100000
#
#        Water Temperature (°C)
# count              665.000000
# mean                26.071278
# std                  3.487633
# min                 17.600000
# 25%                 23.500000
# 50%                 26.500000
# 75%                 28.800000
# max                 34.100000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 665 entries, 0 to 664
# Data columns (total 56 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Water Control Zone                          665 non-null    object
#  1   River                                       665 non-null    object
#  2   Station                                     665 non-null    object
#  3   Dates                                       665 non-null    object
#  4   Sample No                                   665 non-null    int64
#  5   5-Day Biochemical Oxygen Demand (mg/L)      665 non-null    object
#  6   Aluminium (μg/L)                            665 non-null    object
#  7   Ammonia-Nitrogen (mg/L)                     665 non-null    float64
#  8   Anionic Surfactants (as Manoxol OT) (mg/L)  665 non-null    object
#  9   Antimony (μg/L)                             665 non-null    object
#  10  Arsenic (μg/L)                              665 non-null    object
#  11  Barium (μg/L)                               665 non-null    int64
#  12  Beryllium (μg/L)                            665 non-null    object
#  13  Boron (μg/L)                                665 non-null    object
#  14  Cadmium (μg/L)                              665 non-null    object
#  15  Chemical Oxygen Demand (mg/L)               665 non-null    object
#  16  Chloride (mg/L)                             665 non-null    object
#  17  Chlorophyll-𝘢 (mg/m³)                       665 non-null    object
#  18  Chromium (μg/L)                             665 non-null    object
#  19  Conductivity (μS/cm)                        665 non-null    int64
#  20  Copper (μg/L)                               665 non-null    object
#  21  Cyanide (mg/L)                              665 non-null    object
#  22  Dissolved Oxygen (%saturation)              665 non-null    int64
#  23  Dissolved Oxygen (mg/L)                     665 non-null    float64
#  24  Faecal Coliforms (counts/100mL)             665 non-null    object
#  25  Flow (m³/s)                                 428 non-null    float64
#  26  Fluoride (mg/L)                             665 non-null    object
#  27  Free Hydrogen Sulphide (mg/L)               665 non-null    object
#  28  Iron (μg/L)                                 665 non-null    object
#  29  Lead (μg/L)                                 665 non-null    object
#  30  Manganese (μg/L)                            665 non-null    object
#  31  Mercury (μg/L)                              665 non-null    object
#  32  Molybdenum (μg/L)                           665 non-null    object
#  33  Nickel (μg/L)                               665 non-null    object
#  34  Nitrate-Nitrogen (mg/L)                     665 non-null    object
#  35  Nitrite-Nitrogen (mg/L)                     665 non-null    object
#  36  Oil and Grease (mg/L)                       665 non-null    object
#  37  Orthophosphate Phosphorus (mg/L)            665 non-null    object
#  38  pH                                          665 non-null    float64
#  39  Phaeopigment (mg/m³)                        665 non-null    object
#  40  Salinity (psu)                              665 non-null    float64
#  41  Silica (as SiO₂) (mg/L)                     665 non-null    float64
#  42  Silver (μg/L)                               665 non-null    object
#  43  Sulphide (mg/L)                             665 non-null    object
#  44  Suspended solids (mg/L)                     665 non-null    object
#  45  Thallium (μg/L)                             665 non-null    object
#  46  Total Kjeldahl Nitrogen (mg/L)              665 non-null    object
#  47  Total Organic Carbon (mg/L)                 665 non-null    object
#  48  Total Phosphorus (mg/L)                     665 non-null    object
#  49  Total Solids (mg/L)                         665 non-null    int64
#  50  Total Volatile Solids (mg/L)                665 non-null    object
#  51  Turbidity (NTU)                             665 non-null    float64
#  52  Vanadium (μg/L)                             665 non-null    object
#  53  Water Temperature (°C)                      665 non-null    float64
#  54  Zinc (μg/L)                                 665 non-null    object
#  55  𝐸. 𝑐𝑜𝑙𝑖  (counts/100mL)                     665 non-null    object
# dtypes: float64(8), int64(5), object(43)
# memory usage: 291.1+ KB

# %%
data.isnull().sum()
# Out:
# Water Control Zone                              0
# River                                           0
# Station                                         0
# Dates                                           0
# Sample No                                       0
# 5-Day Biochemical Oxygen Demand (mg/L)          0
# Aluminium (μg/L)                                0
# Ammonia-Nitrogen (mg/L)                         0
# Anionic Surfactants (as Manoxol OT) (mg/L)      0
# Antimony (μg/L)                                 0
# Arsenic (μg/L)                                  0
# Barium (μg/L)                                   0
# Beryllium (μg/L)                                0
# Boron (μg/L)                                    0
# Cadmium (μg/L)                                  0
# Chemical Oxygen Demand (mg/L)                   0
# Chloride (mg/L)                                 0
# Chlorophyll-𝘢 (mg/m³)                           0
# Chromium (μg/L)                                 0
# Conductivity (μS/cm)                            0
# Copper (μg/L)                                   0
# Cyanide (mg/L)                                  0
# Dissolved Oxygen (%saturation)                  0
# Dissolved Oxygen (mg/L)                         0
# Faecal Coliforms (counts/100mL)                 0
# Flow (m³/s)                                   237
# Fluoride (mg/L)                                 0
# Free Hydrogen Sulphide (mg/L)                   0
# Iron (μg/L)                                     0
# Lead (μg/L)                                     0
# Manganese (μg/L)                                0
# Mercury (μg/L)                                  0
# Molybdenum (μg/L)                               0
# Nickel (μg/L)                                   0
# Nitrate-Nitrogen (mg/L)                         0
# Nitrite-Nitrogen (mg/L)                         0
# Oil and Grease (mg/L)                           0
# Orthophosphate Phosphorus (mg/L)                0
# pH                                              0
# Phaeopigment (mg/m³)                            0
# Salinity (psu)                                  0
# Silica (as SiO₂) (mg/L)                         0
# Silver (μg/L)                                   0
# Sulphide (mg/L)                                 0
# Suspended solids (mg/L)                         0
# Thallium (μg/L)                                 0
# Total Kjeldahl Nitrogen (mg/L)                  0
# Total Organic Carbon (mg/L)                     0
# Total Phosphorus (mg/L)                         0
# Total Solids (mg/L)                             0
# Total Volatile Solids (mg/L)                    0
# Turbidity (NTU)                                 0
# Vanadium (μg/L)                                 0
# Water Temperature (°C)                          0
# Zinc (μg/L)                                     0
# 𝐸. 𝑐𝑜𝑙𝑖  (counts/100mL)                         0
# dtype: int64

# %%
data = data.drop('Flow (m³/s)',axis=1)

# %%
data.isnull().sum() > 0
# Out:
# Water Control Zone                            False
# River                                         False
# Station                                       False
# Dates                                         False
# Sample No                                     False
# 5-Day Biochemical Oxygen Demand (mg/L)        False
# Aluminium (μg/L)                              False
# Ammonia-Nitrogen (mg/L)                       False
# Anionic Surfactants (as Manoxol OT) (mg/L)    False
# Antimony (μg/L)                               False
# Arsenic (μg/L)                                False
# Barium (μg/L)                                 False
# Beryllium (μg/L)                              False
# Boron (μg/L)                                  False
# Cadmium (μg/L)                                False
# Chemical Oxygen Demand (mg/L)                 False
# Chloride (mg/L)                               False
# Chlorophyll-𝘢 (mg/m³)                         False
# Chromium (μg/L)                               False
# Conductivity (μS/cm)                          False
# Copper (μg/L)                                 False
# Cyanide (mg/L)                                False
# Dissolved Oxygen (%saturation)                False
# Dissolved Oxygen (mg/L)                       False
# Faecal Coliforms (counts/100mL)               False
# Fluoride (mg/L)                               False
# Free Hydrogen Sulphide (mg/L)                 False
# Iron (μg/L)                                   False
# Lead (μg/L)                                   False
# Manganese (μg/L)                              False
# Mercury (μg/L)                                False
# Molybdenum (μg/L)                             False
# Nickel (μg/L)                                 False
# Nitrate-Nitrogen (mg/L)                       False
# Nitrite-Nitrogen (mg/L)                       False
# Oil and Grease (mg/L)                         False
# Orthophosphate Phosphorus (mg/L)              False
# pH                                            False
# Phaeopigment (mg/m³)                          False
# Salinity (psu)                                False
# Silica (as SiO₂) (mg/L)                       False
# Silver (μg/L)                                 False
# Sulphide (mg/L)                               False
# Suspended solids (mg/L)                       False
# Thallium (μg/L)                               False
# Total Kjeldahl Nitrogen (mg/L)                False
# Total Organic Carbon (mg/L)                   False
# Total Phosphorus (mg/L)                       False
# Total Solids (mg/L)                           False
# Total Volatile Solids (mg/L)                  False
# Turbidity (NTU)                               False
# Vanadium (μg/L)                               False
# Water Temperature (°C)                        False
# Zinc (μg/L)                                   False
# 𝐸. 𝑐𝑜𝑙𝑖  (counts/100mL)                       False
# dtype: bool

# %%
X = data.drop(columns=['Faecal Coliforms (counts/100mL)', '𝐸. 𝑐𝑜𝑙𝑖  (counts/100mL)'], axis=1)
y = data[['Faecal Coliforms (counts/100mL)', '𝐸. 𝑐𝑜𝑙𝑖  (counts/100mL)']]

# %%
y
# Out:
#     Faecal Coliforms (counts/100mL) 𝐸. 𝑐𝑜𝑙𝑖  (counts/100mL)
# 0                              2900                      30
# 1                            370000                    7400
# 2                             50000                    1400
# 3                            430000                   10000
# 4                            360000                  320000
# ..                              ...                     ...
# 660                         8500000                 1800000
# 661                        11000000                 4200000
# 662                        30000000                 7900000
# 663                         2900000                 1000000
# 664                         1500000                  810000
#
# [665 rows x 2 columns]

# %%
X.isnull().sum()
# Out:
# Water Control Zone                            0
# River                                         0
# Station                                       0
# Dates                                         0
# Sample No                                     0
# 5-Day Biochemical Oxygen Demand (mg/L)        0
# Aluminium (μg/L)                              0
# Ammonia-Nitrogen (mg/L)                       0
# Anionic Surfactants (as Manoxol OT) (mg/L)    0
# Antimony (μg/L)                               0
# Arsenic (μg/L)                                0
# Barium (μg/L)                                 0
# Beryllium (μg/L)                              0
# Boron (μg/L)                                  0
# Cadmium (μg/L)                                0
# Chemical Oxygen Demand (mg/L)                 0
# Chloride (mg/L)                               0
# Chlorophyll-𝘢 (mg/m³)                         0
# Chromium (μg/L)                               0
# Conductivity (μS/cm)                          0
# Copper (μg/L)                                 0
# Cyanide (mg/L)                                0
# Dissolved Oxygen (%saturation)                0
# Dissolved Oxygen (mg/L)                       0
# Fluoride (mg/L)                               0
# Free Hydrogen Sulphide (mg/L)                 0
# Iron (μg/L)                                   0
# Lead (μg/L)                                   0
# Manganese (μg/L)                              0
# Mercury (μg/L)                                0
# Molybdenum (μg/L)                             0
# Nickel (μg/L)                                 0
# Nitrate-Nitrogen (mg/L)                       0
# Nitrite-Nitrogen (mg/L)                       0
# Oil and Grease (mg/L)                         0
# Orthophosphate Phosphorus (mg/L)              0
# pH                                            0
# Phaeopigment (mg/m³)                          0
# Salinity (psu)                                0
# Silica (as SiO₂) (mg/L)                       0
# Silver (μg/L)                                 0
# Sulphide (mg/L)                               0
# Suspended solids (mg/L)                       0
# Thallium (μg/L)                               0
# Total Kjeldahl Nitrogen (mg/L)                0
# Total Organic Carbon (mg/L)                   0
# Total Phosphorus (mg/L)                       0
# Total Solids (mg/L)                           0
# Total Volatile Solids (mg/L)                  0
# Turbidity (NTU)                               0
# Vanadium (μg/L)                               0
# Water Temperature (°C)                        0
# Zinc (μg/L)                                   0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=25)

# %%
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((532, 53), (133, 53), (532, 2), (133, 2))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

categorical_cols = X.select_dtypes(include=['object']).columns
numeric_cols  = X.select_dtypes(include=['int64']).columns

categorical_cols_indicies = [X.columns.get_loc(col) for col in categorical_cols]
numeric_cols_indicies = [X.columns.get_loc(col) for col in numeric_cols]

ct = ColumnTransformer(
    transformers=[('encoder', OneHotEncoder(handle_unknown='ignore'), categorical_cols_indicies),
                  ('num', StandardScaler(), numeric_cols_indicies)],
    remainder="passthrough"
)

X_train = ct.fit_transform(X_train)
X_valid = ct.transform(X_valid)

# %%
y_train = y_train['']  # Nếu bạn chỉ muốn chọn cột đầu tiên của y_train
# y_train
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (slice(None, None, None), 0)
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 y_train = y_train[:, 0]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3811, in Index.get_loc(self, key)
#    3806 except KeyError as err:
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
# -> 3811         raise InvalidIndexError(key)
#    3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# InvalidIndexError: (slice(None, None, None), 0)

# %%
# Use Gradient Boosting
from sklearn.ensemble import GradientBoostingRegressor

rf_model = GradientBoostingRegressor(n_estimators=1000, learning_rate=0.01, max_depth=5, min_samples_leaf=10, min_samples_split=10)
rf_model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 5
#       2 from sklearn.ensemble import GradientBoostingRegressor
#       4 rf_model = GradientBoostingRegressor(n_estimators=1000, learning_rate=0.01, max_depth=5, min_samples_leaf=10, min_samples_split=10)
# ----> 5 rf_model.fit(X_train, y_train)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:668, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     666 else:
#     667     y = self._encode_y(y=y, sample_weight=sample_weight)
# --> 668 y = column_or_1d(y, warn=True)  # TODO: Is this still required?
#     670 self._set_max_features()
#     672 # self.loss is guaranteed to be a string
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1406, in column_or_1d(y, dtype, warn)
#    1395         warnings.warn(
#    1396             (
#    1397                 "A column-vector y was passed when a 1d array was"
#    (...)
#    1402             stacklevel=2,
#    1403         )
#    1404     return _asarray_with_order(xp.reshape(y, (-1,)), order="C", xp=xp)
# -> 1406 raise ValueError(
#    1407     "y should be a 1d array, got an array of shape {} instead.".format(shape)
#    1408 )
#
# ValueError: y should be a 1d array, got an array of shape (532, 2) instead.
